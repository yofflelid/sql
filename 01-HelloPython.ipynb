# %% [markdown]
# ## 5️⃣ 한 줄 요약 (시험·실무 기준)
#
# - **셀만 바꾸기** → `Esc + M`
# - **아래 마크다운 셀 생성** → `Esc + B + M`
# - **위에 마크다운 셀 생성** → `Esc + A + M`
# - **적용** → `Shift + Enter`
#
# ---
#
# ## 6️⃣ 연주님 기준으로 추천 사용 패턴
#
# 분석 흐름 예시:
#
# 1. `Esc + B + M` → “📌 분석 목적”
# 2. `Shift + Enter`
# 3. `Esc + B + Y` → 코드 셀
# 4. 코드 작성 → `Shift + Enter`
#
# \# 제목 1
# \## 제목 2
# \### 제목 3
#
# \- 목록
# - 목록
#
# **굵게**
# `코드`
#
# ```python
# print("코드 블록")
#
# 마크다운
# Esc → M
#
# 코드
# Esc → Y
#
#
# end
# home

# %% [markdown]
# #2시 40분 부터 ~ 실습 완료 했다고 카톡 보내기 / 그다음에 자율 학습
#
#
# #Lab 01- 파이썬 시작하기, 변수와 연산자

# %% [markdown]
# # Lab 01 - 파이썬 시작하기, 변수와 연산자
#
# ## #03. 첫 번째 프로그램
#
# ### 소스코드 작성하기

# %%
#메시지를 출력하는 명령어 
print("Hello World")
# Out:
# Hello World

# %%
a = 100
b = 200

#합산 결과 출력하기 
print( a + b)
# Out:
# 300

# %% [markdown]
# ## #04. 변수의 이해
#
# ### 다양한 변수 만들기

# %%
# 변수 만들기 (오른쪽에서 왼쪽으로 대입 -> 최초대입을 초기화 라고 함)
# -> 이름 =값 
a=123
b=-456
print(a)
print(b)
# Out:
# 123
# -456

# %%
#한 번 할당된 변수는 다른 값으로 변경 가능 
a=1000
print(a)
# Out:
# 1000

# %%
#실수형 변수 만들기 
c=1.2
d=-3.45
print(c)
print(d)
# Out:
# 1.2
# -3.45

# %% [markdown]
# ### 논리형 변수

# %%
a=True
print(a)
# Out:
# True

# %%
b=False
print(b)
# Out:
# False

# %% [markdown]
# ### 문자열 변수

# %%
#문자열 변수 
msg='안녕하세요. 파이썬'
print(msg)
# Out:
# 안녕하세요. 파이썬

# %%
### 내용이 없는 변수 

hello = None
print(hello)
# Out:
# None

# %% [markdown]
# ## #05. 연산자의 활용
#
# ### 대입 연산자를 활용한 swap 처리

# %%
a=1
b=2
print(a)
print(b)

a, b = b, a
print(a)
print(b)
# Out:
# 1
# 2
# 2
# 1

# %% [markdown]
# ### 산술 연산자 사용하기

# %%
a=3
b=4
c=a+b
print(c)
# Out:
# 7

# %%
print(a-b)
print(a*b)
print(a/b)
# Out:
# -1
# 12
# 0.75

# %% [markdown]
# ### 나눗셈과 거듭제곱

# %%
#나눗셈의 몫을 구한다. 
# ->처리 가능한 단위까지 계산함(마지막 오차발생)
print(10/3)
# Out:
# 3.3333333333333335

# %%
#나눗셈에서 소수점 아래를 버리고 몫만 계산 
print(10//3)
# Out:
# 3

# %%
#나눗셈의 나머지를 구한다. 
# -> 정수 단위에서만 연산 후 종료.
print(10 % 3)
# Out:
# 1

# %%
#거듭제곱 
print(3**5)
# Out:
# 243

# %% [markdown]
# ### 단항 연산자

# %%
a=1
a += 100
#print(a)

a *=  10 
#a

a //= 3
print(a)

a %= 5
print(a)
# Out:
# 336
# 1

# %% [markdown]
# ### 비교 연산자

# %%
#결과값이 True 혹은 False가 된다. 
print(100==50)
print(100 !=50)
print(100 >= 50)
print(100 > 50)
print(100 <= 50)
# Out:
# False
# True
# True
# True
# False

# %%
#비교 연산도 하나의 수식이므로 결과를 다른 변수에 할당 가능함 
result =100 >50
print(result)
# Out:
# True

# %% [markdown]
# ### 논리연산자

# %%
#논리 연산자(and) --> 전체가 True인 경우만 결과값이 True
print( True and True)
print( True and False )
print( False and True) 
print( False and False)
# Out:
# True
# False
# False
# False

# %%
#논리 연산자 (or) --> 하나라도 True가 포함되어 있다면 결과값이 True 
print( True or True)
print( True or False )
print( False or True )
print( False or False )
# Out:
# True
# True
# True
# False

# %%
# True에 대한 부정 
print(not True)

# False에 대한 부정 
print( not False )

# 논리값을 저장하는 변수를 부정하여 그 결과를 다른 변수에 할당 
mybool = True
reverse = not mybool
print(reverse)
# Out:
# False
# True
# False

# %% [markdown]
# ### 비교 연산과 논리 연산의 결합

# %%
#비교연산의 결과값은 bool형식이므로 논리연산이 가능함 
a= 100 >50
b= 20 >10
print( a and b)
# Out:
# True

# %%
# "비교연산자 --> 논리 연산"의 순서로 처리됨

c= 100 >= 100 and 50 == 10
print(c)

print(100 != 200 and 100 == 100)
# Out:
# False
# True

# %% [markdown]
# ### 완전 항등 연산자 'is'

# %%
#비교를 위한 변수값 정의 

x = 100
y = 100.0

# %%
#단순 비교 연산자는 정수와 실수를 구분하지 않는다. 

print( x == y )
print( x != y)
# Out:
# True
# False

# %%
# is 연산자는 비교하는 값의 데이터 타입까지 일치해야만 True 

print( x is y)
print( x is not y)
# Out:
# False
# True
